# %%
from google.colab import files
uploaded = files.upload()  # This allows you to upload a Python (.py) file
# Out:
#      <input type="file" id="files-ea1d86a0-ac71-4dc3-83ae-d81687f23223" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea1d86a0-ac71-4dc3-83ae-d81687f23223">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6434fcbf-9442-474a-876c-ea1b43172e46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6434fcbf-9442-474a-876c-ea1b43172e46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %run Machine_Learning.py
# Out:
# No NaN values in 'desc_1', 'origin', 'roast', or target columns.
# Root Mean Squared Error for each category:
# Aroma: 0.62
# Acid: 0.71
# Body: 0.66
# Flavor: 0.48
# Aftertaste: 0.59
# Enter the cost per 12 ounces (USD): 0.53
# Enter the origin of the coffee: columbia
# Enter the roast level of the coffee (e.g., Light, Medium, Dark): medium
# Enter a brief description of the coffee: floral complex
#
# Predicted Ratings for the input:
# Aroma: 17.30
# Acid: 15.80
# Body: 16.06
# Flavor: 17.64
# Aftertaste: 15.64
#
# Overall Rating predicted is: 82.44
# Website Rating predicted is: 91
